# %%
# Import the dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import requests
from config import api_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations 
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lat,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list 
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities 
cities = []
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name 

    #If the city is unique, then we add it to the list of cities 
    if city not in cities: 
        cities.append(city)
#Print city count to confirm sufficient scount
len(cities)
# Out:
# 773

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + api_key

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=5111746212adb39cfc9e5771cc71d379'

# %%
# Create an endpoint URL for a city 
city_url = url + "&q=" + "Los Angeles"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -118.2437, 'lat': 34.0522},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 61.86,
#   'feels_like': 61.84,
#   'temp_min': 56.95,
#   'temp_max': 72.75,
#   'pressure': 1011,
#   'humidity': 87},
#  'visibility': 10000,
#  'wind': {'speed': 0, 'deg': 0},
#  'clouds': {'all': 1},
#  'dt': 1624710857,
#  'sys': {'type': 1,
#   'id': 3694,
#   'country': 'US',
#   'sunrise': 1624711405,
#   'sunset': 1624763293},
#  'timezone': -25200,
#  'id': 5368361,
#  'name': 'Los Angeles',
#  'cod': 200}

# %%
la_data = city_weather.json()

# %%
lat = la_data["coord"]["lat"]
lng = la_data["coord"]["lon"]
max_temperature = la_data["main"]["temp_max"]
humidity = la_data["main"]["humidity"]
clouds = la_data["clouds"]["all"]
wind = la_data["wind"]["speed"]
weather_desc = la_data["weather"][0]["description"]
print(lat, lng, max_temperature, humidity, clouds, wind, weather_desc)
# Out:
# 34.0522 -118.2437 72.75 87 1 0 clear sky

# %%
city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + api_key

# %%
city_data = []
# Print beginning of logging
print('Beginning Data Retreivel      ')
print("------------------------------")

#create counters
record_count=1
set_count=1
# Out:
# Beginning Data Retreivel
# ------------------------------

# %%
cities
# Out:
# ['busselton',
#  'cabo san lucas',
#  'severo-kurilsk',
#  'kapaa',
#  'tsihombe',
#  'sao filipe',
#  'rikitea',
#  'barentsburg',
#  'bluff',
#  'east london',
#  'mayo',
#  'san jose',
#  'bemidji',
#  'torbay',
#  'jalu',
#  'naze',
#  'jibuti',
#  'khani',
#  'bethel',
#  'khatanga',
#  'zomba',
#  'bambous virieux',
#  'hasaki',
#  'sistranda',
#  'moindou',
#  'hithadhoo',
#  'chuy',
#  'ribeira grande',
#  'klaksvik',
#  'pandan',
#  'ushuaia',
#  'carnarvon',
#  'port alfred',
#  'makakilo city',
#  'saint-joseph',
#  'tuktoyaktuk',
#  'albany',
#  'sysert',
#  'auki',
#  'kjopsvik',
#  'waipawa',
#  'katiola',
#  'kununurra',
#  'kodiak',
#  'avarua',
#  'hermanus',
#  'mar del plata',
#  'pevek',
#  'mitrofanovka',
#  'illoqqortoormiut',
#  'rungata',
#  'punta arenas',
#  'antalaha',
#  'sangar',
#  'hilo',
#  'qasigiannguit',
#  'mataura',
#  'verkhnyaya inta',
#  'dikson',
#  'yellowknife',
#  'sorvag',
#  'cherskiy',
#  'faanui',
#  'mugur-aksy',
#  'henties bay',
#  'krionerion',
#  'anadyr',
#  'bisho',
#  'methoni',
#  'tumannyy',
#  'ilulissat',
#  'narsaq',
#  'tortoli',
#  'acapulco',
#  'ocos',
#  'matagami',
#  'dalbandin',
#  'puerto ayora',
#  'ardistan',
#  'itarema',
#  'chernyshevskiy',
#  'hobart',
#  'manicore',
#  'qaanaaq',
#  'bathsheba',
#  'bengkulu',
#  'nizhneyansk',
#  'mikhaylovka',
#  'isangel',
#  'kamenka',
#  'coihaique',
#  'taolanaro',
#  'butaritari',
#  'barrow',
#  'belushya guba',
#  'broome',
#  'vaini',
#  'tasiilaq',
#  'lebu',
#  'saint-philippe',
#  'lagoa',
#  'gorno-chuyskiy',
#  'half moon bay',
#  'egvekinot',
#  'puerto colombia',
#  'lata',
#  'port elizabeth',
#  'sorland',
#  'mathbaria',
#  'maghama',
#  'conde',
#  'buchanan',
#  'cabedelo',
#  'casablanca',
#  'bredasdorp',
#  'salina',
#  'patan',
#  'murray',
#  'kati',
#  'launceston',
#  'cape town',
#  'jamestown',
#  'iqaluit',
#  'altamira',
#  'chokurdakh',
#  'arroyo',
#  'katsuura',
#  'saskylakh',
#  'porto novo',
#  'amderma',
#  'bitin',
#  'nikolskoye',
#  'avera',
#  'pierre',
#  'cobija',
#  'gat',
#  'aksu',
#  'tena',
#  'port hardy',
#  'saint-francois',
#  'christchurch',
#  'pochutla',
#  'suez',
#  'kyra',
#  'zarubino',
#  'virginia beach',
#  'kathmandu',
#  'raymondville',
#  'barra do garcas',
#  'tiksi',
#  'shihezi',
#  'fairbanks',
#  'yen bai',
#  'ferreira do alentejo',
#  'castro',
#  'atuona',
#  'verkhnevilyuysk',
#  'hofn',
#  'tanout',
#  'bucerias',
#  'lorengau',
#  'celestun',
#  'saldanha',
#  'esperance',
#  'homer',
#  'amboasary',
#  'guarapari',
#  'belaya gora',
#  'avigliano',
#  'muana',
#  'san rafael',
#  'ahipara',
#  'pechenga',
#  'soteapan',
#  'mrirt',
#  'marienburg',
#  'soltvadkert',
#  'martapura',
#  'monte alegre de minas',
#  'mount isa',
#  'karasjok',
#  'mys shmidta',
#  'sholapur',
#  'victoria',
#  'fort nelson',
#  'marand',
#  'shimoda',
#  'miri',
#  'sovetskiy',
#  'bardiyah',
#  'nyrob',
#  'shumskiy',
#  'aykhal',
#  'pemangkat',
#  'taree',
#  'panguipulli',
#  'pouembout',
#  'vardo',
#  'mindelo',
#  'cidreira',
#  'havoysund',
#  'attawapiskat',
#  'mahebourg',
#  'kazerun',
#  'benito juarez',
#  'resavica',
#  'bakchar',
#  'umzimvubu',
#  'odienne',
#  'hobyo',
#  'paita',
#  'nanyuki',
#  'luderitz',
#  'saint george',
#  'vila velha',
#  'jiddah',
#  'molina',
#  'georgetown',
#  'samarai',
#  'lasa',
#  'baykit',
#  'tura',
#  'shetpe',
#  'mildura',
#  'peleduy',
#  'yeppoon',
#  'forbes',
#  'iisalmi',
#  'dunedin',
#  'lakes entrance',
#  'kharp',
#  'longyearbyen',
#  'provideniya',
#  'thompson',
#  'sentyabrskiy',
#  'balarampur',
#  'aden',
#  'comodoro rivadavia',
#  'batemans bay',
#  'saleaula',
#  'todos santos',
#  'dingle',
#  'norman wells',
#  'lapua',
#  'okhotsk',
#  'surt',
#  'new norfolk',
#  'sitka',
#  'kidal',
#  'coffs harbour',
#  'alihe',
#  'rizhao',
#  'oranjestad',
#  'codrington',
#  'louisbourg',
#  'sabibah',
#  'fort saint john',
#  'grand river south east',
#  'nouadhibou',
#  'gonbad-e qabus',
#  'torit',
#  'barawe',
#  'samusu',
#  'derzhavinsk',
#  'ponta do sol',
#  'port blair',
#  'cache creek',
#  'meulaboh',
#  'jiroft',
#  'abu dhabi',
#  'binzhou',
#  'banepa',
#  'geraldton',
#  'mareeba',
#  'arraial do cabo',
#  'upernavik',
#  'pozo colorado',
#  'taoudenni',
#  'sola',
#  'severnoye',
#  'bowen',
#  'urumqi',
#  'suao',
#  'burns lake',
#  'nanortalik',
#  'hambantota',
#  'pathein',
#  'ahuimanu',
#  'great falls',
#  'suzun',
#  'swellendam',
#  'talnakh',
#  'santa isabel do rio negro',
#  'jahrom',
#  'luocheng',
#  'panama city',
#  'quang ngai',
#  'berlevag',
#  'ruatoria',
#  'sur',
#  'zhezkazgan',
#  'vzmorye',
#  'antofagasta',
#  'port hedland',
#  'ballina',
#  'chinsali',
#  'lae',
#  'lavrentiya',
#  'coquimbo',
#  'surman',
#  'raga',
#  'arman',
#  'metro',
#  'axim',
#  'palauig',
#  'husavik',
#  'alofi',
#  'adrar',
#  'mizdah',
#  'kavieng',
#  'kiama',
#  'naryan-mar',
#  'primorka',
#  'valera',
#  'broken hill',
#  'innisfail',
#  'pincher creek',
#  'kruisfontein',
#  'worthington',
#  'padang',
#  'vila franca do campo',
#  'mahibadhoo',
#  'lazaro cardenas',
#  'marcona',
#  'uruzgan',
#  'mazamari',
#  'santa fe',
#  'korla',
#  'montrose',
#  'sambava',
#  'vysokogornyy',
#  'san remo',
#  'pangnirtung',
#  'nome',
#  'tam ky',
#  'castle rock',
#  'raudeberg',
#  'songea',
#  'furstenfeldbruck',
#  'urdoma',
#  'sulangan',
#  'ferrol',
#  'makaleng',
#  'touros',
#  'zhoucheng',
#  'seoul',
#  'cody',
#  'lakota',
#  'lompoc',
#  'talara',
#  'akureyri',
#  'polis',
#  'xuddur',
#  'lage',
#  'dehloran',
#  'marystown',
#  'ak-dovurak',
#  'omsukchan',
#  'nicoya',
#  'iralaya',
#  'svetlogorsk',
#  'tarko-sale',
#  'saint anthony',
#  'srednekolymsk',
#  'taltal',
#  'gangotri',
#  'moron',
#  'marawi',
#  'kuusamo',
#  'akdepe',
#  'canby',
#  'soller',
#  'cedar city',
#  'ingham',
#  'kjollefjord',
#  'maniitsoq',
#  'san isidro',
#  'nepa nagar',
#  'balabac',
#  'kirensk',
#  'kholtoson',
#  'obidos',
#  'sombrerete',
#  'fortuna',
#  'harwich',
#  'yovon',
#  'necochea',
#  'kismayo',
#  'muros',
#  'thinadhoo',
#  'caravelas',
#  'aklavik',
#  'emerald',
#  'poum',
#  'valdivia',
#  'morant bay',
#  'milkovo',
#  'brae',
#  'bac lieu',
#  'ribeira brava',
#  'faya',
#  'ozernovskiy',
#  'yumen',
#  'ugoofaaru',
#  'mahanoro',
#  'sao jose da coroa grande',
#  'ust-kuyga',
#  'sahrak',
#  'morrope',
#  'colorado',
#  'bolungarvik',
#  'bossembele',
#  'aksarka',
#  'mtambile',
#  'ancud',
#  'druzhba',
#  'avanigadda',
#  'california city',
#  'hohhot',
#  'chara',
#  'khuzhir',
#  'conakry',
#  'solsvik',
#  'ulaangom',
#  'ust-kan',
#  'grand centre',
#  'palabuhanratu',
#  'hervey bay',
#  'silikatnyy',
#  'sayanskiy',
#  'monrovia',
#  'aswan',
#  'baghramyan',
#  'nioki',
#  'ozerki',
#  'kaeo',
#  'seydisehir',
#  'port-gentil',
#  'contamana',
#  'sabzevar',
#  'tarakan',
#  'bilibino',
#  'la orilla',
#  'bechem',
#  'nouakchott',
#  'shakiso',
#  'jarjis',
#  'westport',
#  'goderich',
#  'nizhniy bestyakh',
#  'keflavik',
#  'valley city',
#  'parabel',
#  'shibetsu',
#  'soluno-dmitriyevskoye',
#  'aginskoye',
#  'assiniboia',
#  'ileza',
#  'nchelenge',
#  'nerchinskiy zavod',
#  'oranjemund',
#  'waddan',
#  'hay river',
#  'northam',
#  'kota kinabalu',
#  'nazarovo',
#  'onufriyivka',
#  'morlaix',
#  'pacora',
#  'kadykchan',
#  'qingdao',
#  'sosva',
#  'airai',
#  'hisua',
#  'tamiahua',
#  'ratnagiri',
#  'mackay',
#  'palmer',
#  'leningradskiy',
#  'florence',
#  'yar-sale',
#  'sao joao da barra',
#  'lloydminster',
#  'klyuchevskiy',
#  'san patricio',
#  'kysyl-syr',
#  'kendari',
#  'batagay',
#  'svobodnyy',
#  'zyryanka',
#  'kirakira',
#  'isla vista',
#  'saa',
#  'hede',
#  'plettenberg bay',
#  'kletnya',
#  'rayong',
#  'juneau',
#  'kaitangata',
#  'wolbrom',
#  'daru',
#  'karatuzskoye',
#  'san quintin',
#  'boundiali',
#  'mount gambier',
#  'tuy hoa',
#  'kalangala',
#  'warmbad',
#  'souillac',
#  'denpasar',
#  'alta floresta',
#  'obluche',
#  'santa cruz',
#  'vestmannaeyjar',
#  'nemuro',
#  'tamasopo',
#  'miles city',
#  'namibe',
#  'aguimes',
#  'bowmore',
#  'talavera',
#  'marzuq',
#  'buraydah',
#  'alugan',
#  'abnub',
#  'caohai',
#  'boca do acre',
#  'orsk',
#  'port lincoln',
#  'tapah',
#  'cayenne',
#  'sioux lookout',
#  'lubango',
#  'am timan',
#  'vanimo',
#  'bara',
#  'saint-felicien',
#  'pedasi',
#  'namatanai',
#  'belfast',
#  'tonj',
#  'birin',
#  'puerto del rosario',
#  'barao de melgaco',
#  'statesboro',
#  'olafsvik',
#  'havre-saint-pierre',
#  'tuatapere',
#  'ixtapa',
#  'ternate',
#  'bani walid',
#  'loandjili',
#  'flin flon',
#  'najran',
#  'richards bay',
#  'marshalltown',
#  'camana',
#  'rusape',
#  'conceicao do coite',
#  'susaki',
#  'alingsas',
#  'yulara',
#  'sechura',
#  'inta',
#  'salalah',
#  'kinsale',
#  'cambyreta',
#  'zhangye',
#  'golden',
#  'paracuru',
#  'duz',
#  'jacareacanga',
#  'sinnamary',
#  'acajutla',
#  'kavaratti',
#  'ostrovnoy',
#  'rovaniemi',
#  'namwala',
#  'marandahalli',
#  'abashiri',
#  'cruzeiro do sul',
#  'malwan',
#  'powell river',
#  'faratsiho',
#  'bandarbeyla',
#  'riverton',
#  'kushiro',
#  'asilah',
#  'dobele',
#  'kropotkin',
#  'mandalgovi',
#  'duekoue',
#  'turkmenabat',
#  'nijar',
#  'wasilla',
#  'margate',
#  'saint-augustin',
#  'masjed-e soleyman',
#  'sanok',
#  'nhulunbuy',
#  'lujan',
#  'cape coast',
#  'venezuela',
#  'port orange',
#  'tilichiki',
#  'shingu',
#  'hata',
#  'beyneu',
#  'la campana',
#  'maiduguri',
#  'asau',
#  'dumraon',
#  'teguise',
#  'lensk',
#  'kargasok',
#  'athabasca',
#  'keti bandar',
#  'viksoyri',
#  'goundam',
#  'ozgon',
#  'benguela',
#  'omboue',
#  'los llanos de aridane',
#  'guerrero negro',
#  'sterling',
#  'ornskoldsvik',
#  'abalak',
#  'road town',
#  'acarau',
#  'clyde river',
#  'vao',
#  'colombia',
#  'bo phloi',
#  'cerrito',
#  'gijon',
#  'lephepe',
#  'dospat',
#  'nuuk',
#  'winsum',
#  'saint-denis',
#  'wanning',
#  'fukue',
#  'chicama',
#  'kuybysheve',
#  'kieta',
#  'lubao',
#  'manakara',
#  'la palma',
#  'maceio',
#  'motzorongo',
#  'maragogi',
#  'mogadishu',
#  'oxford',
#  'rumford',
#  'troitskoye',
#  'abasolo',
#  'luganville',
#  'porto belo',
#  'xining',
#  'mangai',
#  'roma',
#  'saint-raymond',
#  'constitucion',
#  'bubaque',
#  'damghan',
#  'lenger',
#  'saint-ambroise',
#  'lucapa',
#  'maxixe',
#  'hamilton',
#  'north myrtle beach',
#  'shasta lake',
#  'tsagan aman',
#  'cloquet',
#  'winneba',
#  'humaita',
#  'fevralsk',
#  'boo',
#  'vostok',
#  'beeville',
#  'minas novas',
#  'camacha',
#  'tateyama',
#  'rocha',
#  'antalya',
#  'kijabe',
#  'klyuchi',
#  'pailon',
#  'tunceli',
#  'karratha',
#  'jinchang',
#  'krutikha',
#  'punta',
#  'makeni',
#  'vasai',
#  'timra',
#  'kokopo',
#  'bud',
#  'malmyzh',
#  'bria',
#  'kaya',
#  'dzaoudzi',
#  'tobermory',
#  'tocopilla',
#  'kalmunai',
#  'ust-maya',
#  'college',
#  'te anau',
#  'san carlos de bariloche',
#  'mana',
#  'dinar',
#  'caluquembe',
#  'nishihara',
#  'escanaba',
#  'santo antonio do ica',
#  'sayalgudi',
#  'east stroudsburg',
#  'kungurtug',
#  'torrington',
#  'bacolod',
#  'kawambwa',
#  'taitung',
#  'isiro',
#  'nuevitas',
#  'trenggalek',
#  'morristown',
#  'bargal',
#  'baoro',
#  'collie',
#  'hokitika',
#  'banda aceh',
#  'davila',
#  'elban',
#  'poienile de sub munte',
#  'grand-santi',
#  'derbent',
#  'suluq',
#  'manyana',
#  'grindavik',
#  'bombay',
#  'panacan',
#  'kuah',
#  'podbelsk',
#  'erdenet',
#  'villa constitucion',
#  'dehui',
#  'priladozhskiy',
#  'kayerkan',
#  'kalabo',
#  'manaure',
#  'wulanhaote',
#  'aurangabad',
#  'yatou',
#  'pacific grove',
#  'aranos',
#  'khandyga',
#  'kourou',
#  'la gaulette',
#  'copiapo',
#  'el alto',
#  'kuche',
#  'mnogovershinnyy',
#  'ukiah']

# %%
# Loop through all the cities in list
for i, city in enumerate(cities): 
    
    # Group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count +=1
    # Create endpoint url with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
#     Log the url, record and set numbers and city 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Current Description": city_weather_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | cabo san lucas
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | sao filipe
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | mayo
# Processing Record 12 of Set 1 | san jose
# Processing Record 13 of Set 1 | bemidji
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | jalu
# Processing Record 16 of Set 1 | naze
# Processing Record 17 of Set 1 | jibuti
# Processing Record 18 of Set 1 | khani
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | zomba
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | sistranda
# Processing Record 25 of Set 1 | moindou
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | klaksvik
# Processing Record 30 of Set 1 | pandan
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | makakilo city
# Processing Record 35 of Set 1 | saint-joseph
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | sysert
# Processing Record 39 of Set 1 | auki
# Processing Record 40 of Set 1 | kjopsvik
# Processing Record 41 of Set 1 | waipawa
# Processing Record 42 of Set 1 | katiola
# Processing Record 43 of Set 1 | kununurra
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | mitrofanovka
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 52 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 53 of Set 2 | punta arenas
# Processing Record 54 of Set 2 | antalaha
# Processing Record 55 of Set 2 | sangar
# Processing Record 56 of Set 2 | hilo
# Processing Record 57 of Set 2 | qasigiannguit
# Processing Record 58 of Set 2 | mataura
# Processing Record 59 of Set 2 | verkhnyaya inta
# Processing Record 60 of Set 2 | dikson
# Processing Record 61 of Set 2 | yellowknife
# Processing Record 62 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 63 of Set 2 | cherskiy
# Processing Record 64 of Set 2 | faanui
# Processing Record 65 of Set 2 | mugur-aksy
# Processing Record 66 of Set 2 | henties bay
# Processing Record 67 of Set 2 | krionerion
# City not found. Skipping...
# Processing Record 68 of Set 2 | anadyr
# Processing Record 69 of Set 2 | bisho
# Processing Record 70 of Set 2 | methoni
# Processing Record 71 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 72 of Set 2 | ilulissat
# Processing Record 73 of Set 2 | narsaq
# Processing Record 74 of Set 2 | tortoli
# Processing Record 75 of Set 2 | acapulco
# Processing Record 76 of Set 2 | ocos
# Processing Record 77 of Set 2 | matagami
# Processing Record 78 of Set 2 | dalbandin
# Processing Record 79 of Set 2 | puerto ayora
# Processing Record 80 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 81 of Set 2 | itarema
# Processing Record 82 of Set 2 | chernyshevskiy
# Processing Record 83 of Set 2 | hobart
# Processing Record 84 of Set 2 | manicore
# Processing Record 85 of Set 2 | qaanaaq
# Processing Record 86 of Set 2 | bathsheba
# Processing Record 87 of Set 2 | bengkulu
# Processing Record 88 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 89 of Set 2 | mikhaylovka
# Processing Record 90 of Set 2 | isangel
# Processing Record 91 of Set 2 | kamenka
# Processing Record 92 of Set 2 | coihaique
# Processing Record 93 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 94 of Set 2 | butaritari
# Processing Record 95 of Set 2 | barrow
# Processing Record 96 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 97 of Set 2 | broome
# Processing Record 98 of Set 2 | vaini
# Processing Record 99 of Set 2 | tasiilaq
# Processing Record 100 of Set 2 | lebu
# Processing Record 101 of Set 2 | saint-philippe
# Processing Record 103 of Set 3 | lagoa
# Processing Record 104 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 105 of Set 3 | half moon bay
# Processing Record 106 of Set 3 | egvekinot
# Processing Record 107 of Set 3 | puerto colombia
# Processing Record 108 of Set 3 | lata
# Processing Record 109 of Set 3 | port elizabeth
# Processing Record 110 of Set 3 | sorland
# Processing Record 111 of Set 3 | mathbaria
# Processing Record 112 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 113 of Set 3 | conde
# Processing Record 114 of Set 3 | buchanan
# Processing Record 115 of Set 3 | cabedelo
# Processing Record 116 of Set 3 | casablanca
# Processing Record 117 of Set 3 | bredasdorp
# Processing Record 118 of Set 3 | salina
# Processing Record 119 of Set 3 | patan
# Processing Record 120 of Set 3 | murray
# Processing Record 121 of Set 3 | kati
# Processing Record 122 of Set 3 | launceston
# Processing Record 123 of Set 3 | cape town
# Processing Record 124 of Set 3 | jamestown
# Processing Record 125 of Set 3 | iqaluit
# Processing Record 126 of Set 3 | altamira
# Processing Record 127 of Set 3 | chokurdakh
# Processing Record 128 of Set 3 | arroyo
# Processing Record 129 of Set 3 | katsuura
# Processing Record 130 of Set 3 | saskylakh
# Processing Record 131 of Set 3 | porto novo
# Processing Record 132 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 133 of Set 3 | bitin
# Processing Record 134 of Set 3 | nikolskoye
# Processing Record 135 of Set 3 | avera
# Processing Record 136 of Set 3 | pierre
# Processing Record 137 of Set 3 | cobija
# Processing Record 138 of Set 3 | gat
# Processing Record 139 of Set 3 | aksu
# Processing Record 140 of Set 3 | tena
# Processing Record 141 of Set 3 | port hardy
# Processing Record 142 of Set 3 | saint-francois
# Processing Record 143 of Set 3 | christchurch
# Processing Record 144 of Set 3 | pochutla
# Processing Record 145 of Set 3 | suez
# Processing Record 146 of Set 3 | kyra
# Processing Record 147 of Set 3 | zarubino
# Processing Record 148 of Set 3 | virginia beach
# Processing Record 149 of Set 3 | kathmandu
# Processing Record 150 of Set 3 | raymondville
# Processing Record 151 of Set 3 | barra do garcas
# Processing Record 152 of Set 3 | tiksi
# Processing Record 154 of Set 4 | shihezi
# Processing Record 155 of Set 4 | fairbanks
# Processing Record 156 of Set 4 | yen bai
# Processing Record 157 of Set 4 | ferreira do alentejo
# Processing Record 158 of Set 4 | castro
# Processing Record 159 of Set 4 | atuona
# Processing Record 160 of Set 4 | verkhnevilyuysk
# Processing Record 161 of Set 4 | hofn
# Processing Record 162 of Set 4 | tanout
# Processing Record 163 of Set 4 | bucerias
# Processing Record 164 of Set 4 | lorengau
# Processing Record 165 of Set 4 | celestun
# Processing Record 166 of Set 4 | saldanha
# Processing Record 167 of Set 4 | esperance
# Processing Record 168 of Set 4 | homer
# Processing Record 169 of Set 4 | amboasary
# Processing Record 170 of Set 4 | guarapari
# Processing Record 171 of Set 4 | belaya gora
# Processing Record 172 of Set 4 | avigliano
# Processing Record 173 of Set 4 | muana
# Processing Record 174 of Set 4 | san rafael
# Processing Record 175 of Set 4 | ahipara
# Processing Record 176 of Set 4 | pechenga
# Processing Record 177 of Set 4 | soteapan
# Processing Record 178 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 179 of Set 4 | marienburg
# Processing Record 180 of Set 4 | soltvadkert
# Processing Record 181 of Set 4 | martapura
# Processing Record 182 of Set 4 | monte alegre de minas
# Processing Record 183 of Set 4 | mount isa
# Processing Record 184 of Set 4 | karasjok
# Processing Record 185 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 186 of Set 4 | sholapur
# Processing Record 187 of Set 4 | victoria
# Processing Record 188 of Set 4 | fort nelson
# Processing Record 189 of Set 4 | marand
# Processing Record 190 of Set 4 | shimoda
# Processing Record 191 of Set 4 | miri
# Processing Record 192 of Set 4 | sovetskiy
# Processing Record 193 of Set 4 | bardiyah
# Processing Record 194 of Set 4 | nyrob
# Processing Record 195 of Set 4 | shumskiy
# Processing Record 196 of Set 4 | aykhal
# Processing Record 197 of Set 4 | pemangkat
# Processing Record 198 of Set 4 | taree
# Processing Record 199 of Set 4 | panguipulli
# Processing Record 200 of Set 4 | pouembout
# Processing Record 201 of Set 4 | vardo
# Processing Record 202 of Set 4 | mindelo
# Processing Record 203 of Set 4 | cidreira
# Processing Record 205 of Set 5 | havoysund
# Processing Record 206 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 207 of Set 5 | mahebourg
# Processing Record 208 of Set 5 | kazerun
# Processing Record 209 of Set 5 | benito juarez
# Processing Record 210 of Set 5 | resavica
# Processing Record 211 of Set 5 | bakchar
# Processing Record 212 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 213 of Set 5 | odienne
# Processing Record 214 of Set 5 | hobyo
# Processing Record 215 of Set 5 | paita
# Processing Record 216 of Set 5 | nanyuki
# Processing Record 217 of Set 5 | luderitz
# Processing Record 218 of Set 5 | saint george
# Processing Record 219 of Set 5 | vila velha
# Processing Record 220 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 221 of Set 5 | molina
# Processing Record 222 of Set 5 | georgetown
# Processing Record 223 of Set 5 | samarai
# Processing Record 224 of Set 5 | lasa
# Processing Record 225 of Set 5 | baykit
# Processing Record 226 of Set 5 | tura
# Processing Record 227 of Set 5 | shetpe
# Processing Record 228 of Set 5 | mildura
# Processing Record 229 of Set 5 | peleduy
# Processing Record 230 of Set 5 | yeppoon
# Processing Record 231 of Set 5 | forbes
# Processing Record 232 of Set 5 | iisalmi
# Processing Record 233 of Set 5 | dunedin
# Processing Record 234 of Set 5 | lakes entrance
# Processing Record 235 of Set 5 | kharp
# Processing Record 236 of Set 5 | longyearbyen
# Processing Record 237 of Set 5 | provideniya
# Processing Record 238 of Set 5 | thompson
# Processing Record 239 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 240 of Set 5 | balarampur
# Processing Record 241 of Set 5 | aden
# Processing Record 242 of Set 5 | comodoro rivadavia
# Processing Record 243 of Set 5 | batemans bay
# Processing Record 244 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 245 of Set 5 | todos santos
# Processing Record 246 of Set 5 | dingle
# Processing Record 247 of Set 5 | norman wells
# Processing Record 248 of Set 5 | lapua
# Processing Record 249 of Set 5 | okhotsk
# Processing Record 250 of Set 5 | surt
# Processing Record 251 of Set 5 | new norfolk
# Processing Record 252 of Set 5 | sitka
# Processing Record 253 of Set 5 | kidal
# Processing Record 254 of Set 5 | coffs harbour
# Processing Record 256 of Set 6 | alihe
# Processing Record 257 of Set 6 | rizhao
# Processing Record 258 of Set 6 | oranjestad
# Processing Record 259 of Set 6 | codrington
# Processing Record 260 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 261 of Set 6 | sabibah
# City not found. Skipping...
# Processing Record 262 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 263 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 264 of Set 6 | nouadhibou
# Processing Record 265 of Set 6 | gonbad-e qabus
# Processing Record 266 of Set 6 | torit
# Processing Record 267 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 268 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 269 of Set 6 | derzhavinsk
# Processing Record 270 of Set 6 | ponta do sol
# Processing Record 271 of Set 6 | port blair
# Processing Record 272 of Set 6 | cache creek
# Processing Record 273 of Set 6 | meulaboh
# Processing Record 274 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 275 of Set 6 | abu dhabi
# Processing Record 276 of Set 6 | binzhou
# Processing Record 277 of Set 6 | banepa
# Processing Record 278 of Set 6 | geraldton
# Processing Record 279 of Set 6 | mareeba
# Processing Record 280 of Set 6 | arraial do cabo
# Processing Record 281 of Set 6 | upernavik
# Processing Record 282 of Set 6 | pozo colorado
# Processing Record 283 of Set 6 | taoudenni
# Processing Record 284 of Set 6 | sola
# Processing Record 285 of Set 6 | severnoye
# Processing Record 286 of Set 6 | bowen
# Processing Record 287 of Set 6 | urumqi
# Processing Record 288 of Set 6 | suao
# City not found. Skipping...
# Processing Record 289 of Set 6 | burns lake
# Processing Record 290 of Set 6 | nanortalik
# Processing Record 291 of Set 6 | hambantota
# Processing Record 292 of Set 6 | pathein
# Processing Record 293 of Set 6 | ahuimanu
# Processing Record 294 of Set 6 | great falls
# Processing Record 295 of Set 6 | suzun
# Processing Record 296 of Set 6 | swellendam
# Processing Record 297 of Set 6 | talnakh
# Processing Record 298 of Set 6 | santa isabel do rio negro
# Processing Record 299 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 300 of Set 6 | luocheng
# Processing Record 301 of Set 6 | panama city
# Processing Record 302 of Set 6 | quang ngai
# Processing Record 303 of Set 6 | berlevag
# Processing Record 304 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 305 of Set 6 | sur
# Processing Record 307 of Set 7 | zhezkazgan
# Processing Record 308 of Set 7 | vzmorye
# Processing Record 309 of Set 7 | antofagasta
# Processing Record 310 of Set 7 | port hedland
# Processing Record 311 of Set 7 | ballina
# Processing Record 312 of Set 7 | chinsali
# Processing Record 313 of Set 7 | lae
# Processing Record 314 of Set 7 | lavrentiya
# Processing Record 315 of Set 7 | coquimbo
# Processing Record 316 of Set 7 | surman
# Processing Record 317 of Set 7 | raga
# Processing Record 318 of Set 7 | arman
# Processing Record 319 of Set 7 | metro
# Processing Record 320 of Set 7 | axim
# Processing Record 321 of Set 7 | palauig
# Processing Record 322 of Set 7 | husavik
# Processing Record 323 of Set 7 | alofi
# Processing Record 324 of Set 7 | adrar
# Processing Record 325 of Set 7 | mizdah
# Processing Record 326 of Set 7 | kavieng
# Processing Record 327 of Set 7 | kiama
# Processing Record 328 of Set 7 | naryan-mar
# Processing Record 329 of Set 7 | primorka
# Processing Record 330 of Set 7 | valera
# Processing Record 331 of Set 7 | broken hill
# Processing Record 332 of Set 7 | innisfail
# Processing Record 333 of Set 7 | pincher creek
# Processing Record 334 of Set 7 | kruisfontein
# Processing Record 335 of Set 7 | worthington
# Processing Record 336 of Set 7 | padang
# Processing Record 337 of Set 7 | vila franca do campo
# Processing Record 338 of Set 7 | mahibadhoo
# Processing Record 339 of Set 7 | lazaro cardenas
# Processing Record 340 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 341 of Set 7 | uruzgan
# Processing Record 342 of Set 7 | mazamari
# Processing Record 343 of Set 7 | santa fe
# Processing Record 344 of Set 7 | korla
# Processing Record 345 of Set 7 | montrose
# Processing Record 346 of Set 7 | sambava
# Processing Record 347 of Set 7 | vysokogornyy
# Processing Record 348 of Set 7 | san remo
# Processing Record 349 of Set 7 | pangnirtung
# Processing Record 350 of Set 7 | nome
# Processing Record 351 of Set 7 | tam ky
# Processing Record 352 of Set 7 | castle rock
# Processing Record 353 of Set 7 | raudeberg
# Processing Record 354 of Set 7 | songea
# Processing Record 355 of Set 7 | furstenfeldbruck
# City not found. Skipping...
# Processing Record 356 of Set 7 | urdoma
# Processing Record 358 of Set 8 | sulangan
# Processing Record 359 of Set 8 | ferrol
# Processing Record 360 of Set 8 | makaleng
# Processing Record 361 of Set 8 | touros
# Processing Record 362 of Set 8 | zhoucheng
# Processing Record 363 of Set 8 | seoul
# Processing Record 364 of Set 8 | cody
# Processing Record 365 of Set 8 | lakota
# Processing Record 366 of Set 8 | lompoc
# Processing Record 367 of Set 8 | talara
# Processing Record 368 of Set 8 | akureyri
# Processing Record 369 of Set 8 | polis
# Processing Record 370 of Set 8 | xuddur
# Processing Record 371 of Set 8 | lage
# Processing Record 372 of Set 8 | dehloran
# Processing Record 373 of Set 8 | marystown
# Processing Record 374 of Set 8 | ak-dovurak
# Processing Record 375 of Set 8 | omsukchan
# Processing Record 376 of Set 8 | nicoya
# Processing Record 377 of Set 8 | iralaya
# Processing Record 378 of Set 8 | svetlogorsk
# Processing Record 379 of Set 8 | tarko-sale
# Processing Record 380 of Set 8 | saint anthony
# Processing Record 381 of Set 8 | srednekolymsk
# Processing Record 382 of Set 8 | taltal
# Processing Record 383 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 384 of Set 8 | moron
# Processing Record 385 of Set 8 | marawi
# Processing Record 386 of Set 8 | kuusamo
# Processing Record 387 of Set 8 | akdepe
# Processing Record 388 of Set 8 | canby
# Processing Record 389 of Set 8 | soller
# Processing Record 390 of Set 8 | cedar city
# Processing Record 391 of Set 8 | ingham
# Processing Record 392 of Set 8 | kjollefjord
# Processing Record 393 of Set 8 | maniitsoq
# Processing Record 394 of Set 8 | san isidro
# Processing Record 395 of Set 8 | nepa nagar
# Processing Record 396 of Set 8 | balabac
# Processing Record 397 of Set 8 | kirensk
# Processing Record 398 of Set 8 | kholtoson
# Processing Record 399 of Set 8 | obidos
# Processing Record 400 of Set 8 | sombrerete
# Processing Record 401 of Set 8 | fortuna
# Processing Record 402 of Set 8 | harwich
# Processing Record 403 of Set 8 | yovon
# Processing Record 404 of Set 8 | necochea
# Processing Record 405 of Set 8 | kismayo
# Processing Record 406 of Set 8 | muros
# Processing Record 407 of Set 8 | thinadhoo
# Processing Record 409 of Set 9 | caravelas
# Processing Record 410 of Set 9 | aklavik
# Processing Record 411 of Set 9 | emerald
# Processing Record 412 of Set 9 | poum
# Processing Record 413 of Set 9 | valdivia
# Processing Record 414 of Set 9 | morant bay
# Processing Record 415 of Set 9 | milkovo
# Processing Record 416 of Set 9 | brae
# Processing Record 417 of Set 9 | bac lieu
# Processing Record 418 of Set 9 | ribeira brava
# Processing Record 419 of Set 9 | faya
# Processing Record 420 of Set 9 | ozernovskiy
# Processing Record 421 of Set 9 | yumen
# Processing Record 422 of Set 9 | ugoofaaru
# Processing Record 423 of Set 9 | mahanoro
# Processing Record 424 of Set 9 | sao jose da coroa grande
# Processing Record 425 of Set 9 | ust-kuyga
# Processing Record 426 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 427 of Set 9 | morrope
# Processing Record 428 of Set 9 | colorado
# Processing Record 429 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 430 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 431 of Set 9 | aksarka
# Processing Record 432 of Set 9 | mtambile
# Processing Record 433 of Set 9 | ancud
# Processing Record 434 of Set 9 | druzhba
# Processing Record 435 of Set 9 | avanigadda
# Processing Record 436 of Set 9 | california city
# Processing Record 437 of Set 9 | hohhot
# Processing Record 438 of Set 9 | chara
# Processing Record 439 of Set 9 | khuzhir
# Processing Record 440 of Set 9 | conakry
# Processing Record 441 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 442 of Set 9 | ulaangom
# Processing Record 443 of Set 9 | ust-kan
# Processing Record 444 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 445 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 446 of Set 9 | hervey bay
# Processing Record 447 of Set 9 | silikatnyy
# Processing Record 448 of Set 9 | sayanskiy
# City not found. Skipping...
# Processing Record 449 of Set 9 | monrovia
# Processing Record 450 of Set 9 | aswan
# Processing Record 451 of Set 9 | baghramyan
# Processing Record 452 of Set 9 | nioki
# Processing Record 453 of Set 9 | ozerki
# Processing Record 454 of Set 9 | kaeo
# Processing Record 455 of Set 9 | seydisehir
# Processing Record 456 of Set 9 | port-gentil
# Processing Record 457 of Set 9 | contamana
# Processing Record 458 of Set 9 | sabzevar
# Processing Record 460 of Set 10 | tarakan
# Processing Record 461 of Set 10 | bilibino
# Processing Record 462 of Set 10 | la orilla
# Processing Record 463 of Set 10 | bechem
# Processing Record 464 of Set 10 | nouakchott
# Processing Record 465 of Set 10 | shakiso
# Processing Record 466 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 467 of Set 10 | westport
# Processing Record 468 of Set 10 | goderich
# Processing Record 469 of Set 10 | nizhniy bestyakh
# Processing Record 470 of Set 10 | keflavik
# Processing Record 471 of Set 10 | valley city
# Processing Record 472 of Set 10 | parabel
# Processing Record 473 of Set 10 | shibetsu
# Processing Record 474 of Set 10 | soluno-dmitriyevskoye
# Processing Record 475 of Set 10 | aginskoye
# Processing Record 476 of Set 10 | assiniboia
# Processing Record 477 of Set 10 | ileza
# Processing Record 478 of Set 10 | nchelenge
# Processing Record 479 of Set 10 | nerchinskiy zavod
# Processing Record 480 of Set 10 | oranjemund
# Processing Record 481 of Set 10 | waddan
# Processing Record 482 of Set 10 | hay river
# Processing Record 483 of Set 10 | northam
# Processing Record 484 of Set 10 | kota kinabalu
# Processing Record 485 of Set 10 | nazarovo
# Processing Record 486 of Set 10 | onufriyivka
# Processing Record 487 of Set 10 | morlaix
# Processing Record 488 of Set 10 | pacora
# Processing Record 489 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 490 of Set 10 | qingdao
# Processing Record 491 of Set 10 | sosva
# Processing Record 492 of Set 10 | airai
# Processing Record 493 of Set 10 | hisua
# Processing Record 494 of Set 10 | tamiahua
# Processing Record 495 of Set 10 | ratnagiri
# Processing Record 496 of Set 10 | mackay
# Processing Record 497 of Set 10 | palmer
# Processing Record 498 of Set 10 | leningradskiy
# Processing Record 499 of Set 10 | florence
# Processing Record 500 of Set 10 | yar-sale
# Processing Record 501 of Set 10 | sao joao da barra
# Processing Record 502 of Set 10 | lloydminster
# Processing Record 503 of Set 10 | klyuchevskiy
# Processing Record 504 of Set 10 | san patricio
# Processing Record 505 of Set 10 | kysyl-syr
# Processing Record 506 of Set 10 | kendari
# Processing Record 507 of Set 10 | batagay
# Processing Record 508 of Set 10 | svobodnyy
# Processing Record 509 of Set 10 | zyryanka
# Processing Record 511 of Set 11 | kirakira
# Processing Record 512 of Set 11 | isla vista
# Processing Record 513 of Set 11 | saa
# Processing Record 514 of Set 11 | hede
# Processing Record 515 of Set 11 | plettenberg bay
# Processing Record 516 of Set 11 | kletnya
# Processing Record 517 of Set 11 | rayong
# Processing Record 518 of Set 11 | juneau
# Processing Record 519 of Set 11 | kaitangata
# Processing Record 520 of Set 11 | wolbrom
# Processing Record 521 of Set 11 | daru
# Processing Record 522 of Set 11 | karatuzskoye
# Processing Record 523 of Set 11 | san quintin
# Processing Record 524 of Set 11 | boundiali
# Processing Record 525 of Set 11 | mount gambier
# Processing Record 526 of Set 11 | tuy hoa
# Processing Record 527 of Set 11 | kalangala
# Processing Record 528 of Set 11 | warmbad
# Processing Record 529 of Set 11 | souillac
# Processing Record 530 of Set 11 | denpasar
# Processing Record 531 of Set 11 | alta floresta
# Processing Record 532 of Set 11 | obluche
# City not found. Skipping...
# Processing Record 533 of Set 11 | santa cruz
# Processing Record 534 of Set 11 | vestmannaeyjar
# Processing Record 535 of Set 11 | nemuro
# Processing Record 536 of Set 11 | tamasopo
# Processing Record 537 of Set 11 | miles city
# Processing Record 538 of Set 11 | namibe
# Processing Record 539 of Set 11 | aguimes
# Processing Record 540 of Set 11 | bowmore
# Processing Record 541 of Set 11 | talavera
# Processing Record 542 of Set 11 | marzuq
# Processing Record 543 of Set 11 | buraydah
# Processing Record 544 of Set 11 | alugan
# Processing Record 545 of Set 11 | abnub
# Processing Record 546 of Set 11 | caohai
# Processing Record 547 of Set 11 | boca do acre
# Processing Record 548 of Set 11 | orsk
# Processing Record 549 of Set 11 | port lincoln
# Processing Record 550 of Set 11 | tapah
# Processing Record 551 of Set 11 | cayenne
# Processing Record 552 of Set 11 | sioux lookout
# Processing Record 553 of Set 11 | lubango
# Processing Record 554 of Set 11 | am timan
# Processing Record 555 of Set 11 | vanimo
# Processing Record 556 of Set 11 | bara
# Processing Record 557 of Set 11 | saint-felicien
# Processing Record 558 of Set 11 | pedasi
# Processing Record 559 of Set 11 | namatanai
# Processing Record 560 of Set 11 | belfast
# Processing Record 562 of Set 12 | tonj
# Processing Record 563 of Set 12 | birin
# Processing Record 564 of Set 12 | puerto del rosario
# Processing Record 565 of Set 12 | barao de melgaco
# Processing Record 566 of Set 12 | statesboro
# Processing Record 567 of Set 12 | olafsvik
# Processing Record 568 of Set 12 | havre-saint-pierre
# Processing Record 569 of Set 12 | tuatapere
# Processing Record 570 of Set 12 | ixtapa
# Processing Record 571 of Set 12 | ternate
# Processing Record 572 of Set 12 | bani walid
# Processing Record 573 of Set 12 | loandjili
# Processing Record 574 of Set 12 | flin flon
# Processing Record 575 of Set 12 | najran
# Processing Record 576 of Set 12 | richards bay
# Processing Record 577 of Set 12 | marshalltown
# Processing Record 578 of Set 12 | camana
# Processing Record 579 of Set 12 | rusape
# Processing Record 580 of Set 12 | conceicao do coite
# Processing Record 581 of Set 12 | susaki
# Processing Record 582 of Set 12 | alingsas
# Processing Record 583 of Set 12 | yulara
# Processing Record 584 of Set 12 | sechura
# Processing Record 585 of Set 12 | inta
# Processing Record 586 of Set 12 | salalah
# Processing Record 587 of Set 12 | kinsale
# Processing Record 588 of Set 12 | cambyreta
# City not found. Skipping...
# Processing Record 589 of Set 12 | zhangye
# Processing Record 590 of Set 12 | golden
# Processing Record 591 of Set 12 | paracuru
# Processing Record 592 of Set 12 | duz
# City not found. Skipping...
# Processing Record 593 of Set 12 | jacareacanga
# Processing Record 594 of Set 12 | sinnamary
# Processing Record 595 of Set 12 | acajutla
# Processing Record 596 of Set 12 | kavaratti
# Processing Record 597 of Set 12 | ostrovnoy
# Processing Record 598 of Set 12 | rovaniemi
# Processing Record 599 of Set 12 | namwala
# Processing Record 600 of Set 12 | marandahalli
# Processing Record 601 of Set 12 | abashiri
# Processing Record 602 of Set 12 | cruzeiro do sul
# Processing Record 603 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 604 of Set 12 | powell river
# Processing Record 605 of Set 12 | faratsiho
# Processing Record 606 of Set 12 | bandarbeyla
# Processing Record 607 of Set 12 | riverton
# Processing Record 608 of Set 12 | kushiro
# Processing Record 609 of Set 12 | asilah
# Processing Record 610 of Set 12 | dobele
# Processing Record 611 of Set 12 | kropotkin
# Processing Record 613 of Set 13 | mandalgovi
# Processing Record 614 of Set 13 | duekoue
# Processing Record 615 of Set 13 | turkmenabat
# Processing Record 616 of Set 13 | nijar
# Processing Record 617 of Set 13 | wasilla
# Processing Record 618 of Set 13 | margate
# Processing Record 619 of Set 13 | saint-augustin
# Processing Record 620 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 621 of Set 13 | sanok
# Processing Record 622 of Set 13 | nhulunbuy
# Processing Record 623 of Set 13 | lujan
# Processing Record 624 of Set 13 | cape coast
# Processing Record 625 of Set 13 | venezuela
# Processing Record 626 of Set 13 | port orange
# Processing Record 627 of Set 13 | tilichiki
# Processing Record 628 of Set 13 | shingu
# Processing Record 629 of Set 13 | hata
# Processing Record 630 of Set 13 | beyneu
# Processing Record 631 of Set 13 | la campana
# Processing Record 632 of Set 13 | maiduguri
# Processing Record 633 of Set 13 | asau
# Processing Record 634 of Set 13 | dumraon
# Processing Record 635 of Set 13 | teguise
# Processing Record 636 of Set 13 | lensk
# Processing Record 637 of Set 13 | kargasok
# Processing Record 638 of Set 13 | athabasca
# Processing Record 639 of Set 13 | keti bandar
# Processing Record 640 of Set 13 | viksoyri
# City not found. Skipping...
# Processing Record 641 of Set 13 | goundam
# Processing Record 642 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 643 of Set 13 | benguela
# Processing Record 644 of Set 13 | omboue
# Processing Record 645 of Set 13 | los llanos de aridane
# Processing Record 646 of Set 13 | guerrero negro
# Processing Record 647 of Set 13 | sterling
# Processing Record 648 of Set 13 | ornskoldsvik
# Processing Record 649 of Set 13 | abalak
# Processing Record 650 of Set 13 | road town
# Processing Record 651 of Set 13 | acarau
# Processing Record 652 of Set 13 | clyde river
# Processing Record 653 of Set 13 | vao
# Processing Record 654 of Set 13 | colombia
# Processing Record 655 of Set 13 | bo phloi
# Processing Record 656 of Set 13 | cerrito
# Processing Record 657 of Set 13 | gijon
# Processing Record 658 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 659 of Set 13 | dospat
# Processing Record 660 of Set 13 | nuuk
# Processing Record 661 of Set 13 | winsum
# Processing Record 662 of Set 13 | saint-denis
# Processing Record 664 of Set 14 | wanning
# Processing Record 665 of Set 14 | fukue
# Processing Record 666 of Set 14 | chicama
# Processing Record 667 of Set 14 | kuybysheve
# Processing Record 668 of Set 14 | kieta
# Processing Record 669 of Set 14 | lubao
# Processing Record 670 of Set 14 | manakara
# Processing Record 671 of Set 14 | la palma
# Processing Record 672 of Set 14 | maceio
# Processing Record 673 of Set 14 | motzorongo
# Processing Record 674 of Set 14 | maragogi
# Processing Record 675 of Set 14 | mogadishu
# Processing Record 676 of Set 14 | oxford
# Processing Record 677 of Set 14 | rumford
# Processing Record 678 of Set 14 | troitskoye
# Processing Record 679 of Set 14 | abasolo
# Processing Record 680 of Set 14 | luganville
# Processing Record 681 of Set 14 | porto belo
# Processing Record 682 of Set 14 | xining
# Processing Record 683 of Set 14 | mangai
# Processing Record 684 of Set 14 | roma
# Processing Record 685 of Set 14 | saint-raymond
# Processing Record 686 of Set 14 | constitucion
# Processing Record 687 of Set 14 | bubaque
# Processing Record 688 of Set 14 | damghan
# Processing Record 689 of Set 14 | lenger
# Processing Record 690 of Set 14 | saint-ambroise
# Processing Record 691 of Set 14 | lucapa
# Processing Record 692 of Set 14 | maxixe
# Processing Record 693 of Set 14 | hamilton
# Processing Record 694 of Set 14 | north myrtle beach
# Processing Record 695 of Set 14 | shasta lake
# Processing Record 696 of Set 14 | tsagan aman
# Processing Record 697 of Set 14 | cloquet
# Processing Record 698 of Set 14 | winneba
# Processing Record 699 of Set 14 | humaita
# Processing Record 700 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 701 of Set 14 | boo
# Processing Record 702 of Set 14 | vostok
# Processing Record 703 of Set 14 | beeville
# Processing Record 704 of Set 14 | minas novas
# Processing Record 705 of Set 14 | camacha
# Processing Record 706 of Set 14 | tateyama
# Processing Record 707 of Set 14 | rocha
# Processing Record 708 of Set 14 | antalya
# Processing Record 709 of Set 14 | kijabe
# Processing Record 710 of Set 14 | klyuchi
# Processing Record 711 of Set 14 | pailon
# Processing Record 712 of Set 14 | tunceli
# Processing Record 713 of Set 14 | karratha
# Processing Record 715 of Set 15 | jinchang
# Processing Record 716 of Set 15 | krutikha
# Processing Record 717 of Set 15 | punta
# Processing Record 718 of Set 15 | makeni
# Processing Record 719 of Set 15 | vasai
# Processing Record 720 of Set 15 | timra
# Processing Record 721 of Set 15 | kokopo
# Processing Record 722 of Set 15 | bud
# Processing Record 723 of Set 15 | malmyzh
# Processing Record 724 of Set 15 | bria
# Processing Record 725 of Set 15 | kaya
# Processing Record 726 of Set 15 | dzaoudzi
# Processing Record 727 of Set 15 | tobermory
# Processing Record 728 of Set 15 | tocopilla
# Processing Record 729 of Set 15 | kalmunai
# Processing Record 730 of Set 15 | ust-maya
# Processing Record 731 of Set 15 | college
# Processing Record 732 of Set 15 | te anau
# Processing Record 733 of Set 15 | san carlos de bariloche
# Processing Record 734 of Set 15 | mana
# Processing Record 735 of Set 15 | dinar
# Processing Record 736 of Set 15 | caluquembe
# Processing Record 737 of Set 15 | nishihara
# Processing Record 738 of Set 15 | escanaba
# Processing Record 739 of Set 15 | santo antonio do ica
# Processing Record 740 of Set 15 | sayalgudi
# City not found. Skipping...
# Processing Record 741 of Set 15 | east stroudsburg
# Processing Record 742 of Set 15 | kungurtug
# Processing Record 743 of Set 15 | torrington
# Processing Record 744 of Set 15 | bacolod
# Processing Record 745 of Set 15 | kawambwa
# Processing Record 746 of Set 15 | taitung
# Processing Record 747 of Set 15 | isiro
# Processing Record 748 of Set 15 | nuevitas
# Processing Record 749 of Set 15 | trenggalek
# Processing Record 750 of Set 15 | morristown
# Processing Record 751 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 752 of Set 15 | baoro
# Processing Record 753 of Set 15 | collie
# Processing Record 754 of Set 15 | hokitika
# Processing Record 755 of Set 15 | banda aceh
# Processing Record 756 of Set 15 | davila
# Processing Record 757 of Set 15 | elban
# Processing Record 758 of Set 15 | poienile de sub munte
# Processing Record 759 of Set 15 | grand-santi
# Processing Record 760 of Set 15 | derbent
# Processing Record 761 of Set 15 | suluq
# Processing Record 762 of Set 15 | manyana
# Processing Record 763 of Set 15 | grindavik
# Processing Record 764 of Set 15 | bombay
# Processing Record 766 of Set 16 | panacan
# Processing Record 767 of Set 16 | kuah
# Processing Record 768 of Set 16 | podbelsk
# City not found. Skipping...
# Processing Record 769 of Set 16 | erdenet
# Processing Record 770 of Set 16 | villa constitucion
# Processing Record 771 of Set 16 | dehui
# Processing Record 772 of Set 16 | priladozhskiy
# Processing Record 773 of Set 16 | kayerkan
# Processing Record 774 of Set 16 | kalabo
# Processing Record 775 of Set 16 | manaure
# Processing Record 776 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 777 of Set 16 | aurangabad
# Processing Record 778 of Set 16 | yatou
# Processing Record 779 of Set 16 | pacific grove
# Processing Record 780 of Set 16 | aranos
# Processing Record 781 of Set 16 | khandyga
# Processing Record 782 of Set 16 | kourou
# Processing Record 783 of Set 16 | la gaulette
# City not found. Skipping...
# Processing Record 784 of Set 16 | copiapo
# Processing Record 785 of Set 16 | el alto
# Processing Record 786 of Set 16 | kuche
# City not found. Skipping...
# Processing Record 787 of Set 16 | mnogovershinnyy
# Processing Record 788 of Set 16 | ukiah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_df = pd.DataFrame(city_data)
weather_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.6500  115.3333     48.99        90           0
# 1  Cabo San Lucas      MX  22.8909 -109.9124     82.81        57          75
# 2  Severo-Kurilsk      RU  50.6789  156.1250     42.73        94          42
# 3           Kapaa      US  22.0752 -159.3190     73.72        70           1
# 4      Sao Filipe      CV  14.8961  -24.4956     77.61        75         100
# 5         Rikitea      PF -23.1203 -134.9692     73.65        74           1
# 6           Bluff      NZ -46.6000  168.3333     45.81        92          67
# 7     East London      ZA -33.0153   27.9116     74.34        23           0
# 8            Mayo      US  38.8876  -76.5119     78.04        85          75
# 9        San Jose      US  37.3394 -121.8950     62.28        84          90
#
#    Wind Speed Current Description
# 0        3.00           clear sky
# 1        4.00       broken clouds
# 2       14.65    scattered clouds
# 3        1.01           clear sky
# 4        4.76     overcast clouds
# 5        4.94           clear sky
# 6        7.96       broken clouds
# 7       20.71           clear sky
# 8        4.00       broken clouds
# 9        5.75     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "weather_database.csv"

# %%
# Export the City Data into a csv
weather_df.to_csv(output_data_file, index_label="City_ID")
